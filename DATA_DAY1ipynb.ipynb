# %% [markdown]
# <a href="https://colab.research.google.com/github/siddharth10-dev/data-viz-python/blob/main/DATA_DAY1ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import numpy as np

# %%
#comment of the data

# %%
print("data day 1")
# Out:
# data day 1

# %%
a = np.array([1,2,3,4])
print(a[0],a[1])
# Out:
# 1 2

# %%
a[0:]
# Out:
# array([1, 2, 3, 4])

# %%
a[1:3]
# Out:
# array([2, 3])

# %%
a[::2]
# Out:
# array([1, 3])

# %%
a.dtype
# Out:
# dtype('int64')

# %%
b=np.array([0.5,0.1,1.5])

# %%
b[1:]
# Out:
# array([0.1, 1.5])

# %%
A = np.array([
    [1,2,3],
    [4,5,6]
])

# %%
A.shape
# Out:
# (2, 3)

# %%
A.ndim
# Out:
# 2

# %%
A.size
# Out:
# 6

# %%
A = np.arange(5)
A+20
# Out:
# array([20, 21, 22, 23, 24])

# %%
B=np.arange(6)
B
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
B+30
# Out:
# array([30, 31, 32, 33, 34, 35])

# %%
B=B+30

# %%
B
# Out:
# array([30, 31, 32, 33, 34, 35])

# %%
#BOOLEAN ARRAYS(masks)

# %%
c = np.arange(5)

# %%
c<=3
# Out:
# array([ True,  True,  True,  True, False])
